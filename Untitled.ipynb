# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
red = pd.read_csv('data/raw/winequality-red.csv',sep=';')
white = pd.read_csv('data/raw/winequality-white.csv',sep=';')
red 
from project_function import load_and_process
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df2=load_and_process(red)
df2
## Here I am interested in the relationship between the value of alcohol,chloridesand volatile acidity and quality. 
##They seem to have positive relationship.
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
boxplot=red.boxplot()
##I have noticed that the values varies in wide range so it is hard to see the each column has the outlier or not. 
##So I decided to find the maximum value for each column and put them in group by the maximum value to create boxplot.

# %%
red.max()

# %%
boxplot_density=red.boxplot(column="density") ##The max value was pretty small compared to other columns so 
##so I created a boxplot for density and I found the outlier.

# %%
boxplot1=red.boxplot(column=["volatile acidity","citric acid","chlorides","pH","sulphates"])
##Max value is less than 5.0. There are outlier for all columns

# %%
boxplot=red.boxplot(column=["fixed acidity","residual sugar","alcohol"]) ##Max value is less than 20.0
##Here also outliers were found for each columns

# %%
Q1=red.quantile(0.25)
Q3=red.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# fixed acidity            2.100000
# volatile acidity         0.250000
# citric acid              0.330000
# residual sugar           0.700000
# chlorides                0.020000
# free sulfur dioxide     14.000000
# total sulfur dioxide    40.000000
# density                  0.002235
# pH                       0.190000
# sulphates                0.180000
# alcohol                  1.600000
# quality                  1.000000
# dtype: float64

# %%
upper=Q3+1.5*IQR
lower=Q1+1.5*IQR
##red=red.drop('fixed acidity',axis=1)
##red
##red2=red[(red>upper)&(red<lower)]
##red2
##red3 = red[~((red ["density"] < lower) |(df["density"] > upper))]
# Out:
#       volatile acidity  citric acid  residual sugar  chlorides  \
# 0                0.700         0.00             1.9      0.076
# 1                0.880         0.00             2.6      0.098
# 2                0.760         0.04             2.3      0.092
# 3                0.280         0.56             1.9      0.075
# 4                0.700         0.00             1.9      0.076
# ...                ...          ...             ...        ...
# 1594             0.600         0.08             2.0      0.090
# 1595             0.550         0.10             2.2      0.062
# 1596             0.510         0.13             2.3      0.076
# 1597             0.645         0.12             2.0      0.075
# 1598             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# ...

# %%
##plt.figure(figsize=(8,6))
p1 = sns.jointplot(data=red,x='alcohol',y='quality')
p1

# %%
df3=load_and_process(white)
df3
##Here I noticed that white wine hit the quality of 9 that red wine did not.
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %%
display(df2.iloc[5]) ##Mean of quality of 8 of red wine 
display(df3.iloc[6]) ##Mean of quality of 9 of white wine
# Out:
# fixed acidity              8.566667
# volatile acidity           0.423333
# citric acid                0.391111
# residual sugar             2.577778
# chlorides                  0.068444
# free sulfur dioxide       13.277778
# total sulfur dioxide      33.444444
# density                    0.995212
# pH                         3.267222
# sulphates                  0.767778
# alcohol                   12.094444
# slope_quality_alchohol     0.668146
# Name: 8, dtype: float64
# fixed acidity               7.420000
# volatile acidity            0.298000
# citric acid                 0.386000
# residual sugar              4.120000
# chlorides                   0.027400
# free sulfur dioxide        33.400000
# total sulfur dioxide      116.000000
# density                     0.991460
# pH                          3.308000
# sulphates                   0.466000
# alcohol                    12.180000
# slope_quality_alchohol      0.743505
# Name: 9, dtype: float64

# %%
##So there is

# %%
red=red.sort_values(by=['quality'])
red
red.min()
red.max()
# Out:
# volatile acidity          1.58000
# citric acid               1.00000
# residual sugar           15.50000
# chlorides                 0.61100
# free sulfur dioxide      72.00000
# total sulfur dioxide    289.00000
# density                   1.00369
# pH                        4.01000
# sulphates                 2.00000
# alcohol                  14.90000
# quality                   8.00000
# dtype: float64

# %%
g=sns.JointGrid(data=red,x='alcohol',y='quality',xlim=(8.0,15),ylim=(3,8))
